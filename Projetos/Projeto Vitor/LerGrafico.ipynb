# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
plt.rcParams.update({
    #"axes.unicode_minus" : False,
    "font.family": "serif",  # use serif/main font for text elements
    "font.serif" : "Computer Modern Roman",
    "font.sans-serif" : "Computer Modern Sans serif",
    "font.monospace"  : "Computer Modern Typewriter",
    "font.weight"   :   "bold",
    #"text.usetex": True,     # use inline math for ticks
    #"pgf.rcfonts": False,    # don't setup fonts from rc parameters   
    "figure.figsize": [10,5],
    #"axes.titlesize": "xx-large",   # fontsize oarqthe axes title
    #"axes.labelsize": "xx-large",  # fontsize of the x any y labels
    #"xtick.labelsize": "xx-large",  # font size of the tick labels
    #"ytick.labelsize": "xx-large",  # font size of the tick labels
    #"legend.fontsize":   "large",
    #"pgf.preamble": "\n".join([
         #r"\usepackage{url}",            # load additional packages
         #r"\usepackage{unicode-math}",   # unicode math setup
         #r"\setmainfont{DejaVu Serif}",  # serif font via preamble

    #])
})


# assign directory
pasta = "Gráficos"
i = 0

for arquivo in os.listdir(pasta):
    if arquivo[-3:] == "asc":
        f = os.path.join(pasta, arquivo)
        # checking if it is a file
        if os.path.isfile(f):
            titulo = open(f, "r").readlines()[8][:-24]

            nome = np.loadtxt(f, skiprows = 55)
            #for file in 
            data = np.loadtxt(f, skiprows = 55)
            i = i + 1

            dataX = []
            dataY = []
            for linha in data:
                dataX.append(linha[0])
                dataY.append(linha[1])

            plt.figure(i)
            plt.plot(dataX,dataY)
            plt.xlabel(r'Número de onda ($cm^{-1})$', fontweight='bold')
            plt.ylabel('Reflectância (u.a)', fontweight='bold')
            plt.xlim(dataX[0],dataX[-1])
            plt.ylim(min(dataY),max(dataY)+1)
            plt.title(titulo + ' - ' + arquivo[0:-4])

            plt.savefig(os.path.join(pasta,arquivo[:8]) + '.jpg')
            plt.savefig(os.path.join(pasta,arquivo[:8]) + '.png')
            #print(arquivo[:8] + '.txt')
            #plt.close()

# %%
# assign directory
pasta = "Gráficos"
i = 0

f = os.path.join(pasta, "Fr220605.asc")
# checking if it is a file
if os.path.isfile(f):

    #for file in 
    data = np.loadtxt(f, skiprows = 55)
    i = i + 1

    dataX = []
    dataY = []
    for linha in data:
        dataX.append(linha[0])
        dataY.append(linha[1])

    #dataX.reverse()
    #dataY.reverse()
    #dataX = dataX.reverse()
    #dataY = dataY.reverse()

    plt.figure(i, figsize = [16,8])
    plt.plot(dataX,dataY)
    plt.xlim(dataX[0],dataX[-1])
    plt.title('Granalhas de endocarpo sem tratamento - Fr220605')
    plt.xlabel(r'Número de onda ($cm^{-1})$', fontweight='bold')
    plt.ylabel('Reflectância (u.a)', fontweight='bold')
    plt.ylim(min(dataY),max(dataY)+1)

    #plt.plot(2923.52, 93.35,"ro")
    plt.axvline(x = 2923.52, ymin = 0, ymax = 0.70, color = 'gray', linestyle = '--')

    #plt.plot(1032.00, 74.951206,"ro")
    plt.annotate('', xy=(1032.74, 74.951206), xytext=(0.75, 0.1), textcoords='axes fraction', arrowprops=dict(color='red', shrink=0.05),horizontalalignment='right', verticalalignment='top',)
    #plt.axhline(y = 74.951206, xmin = 0, xmax = 0.86, color = 'gray', linestyle = '--')
    plt.axvline(x = 1032.06, ymin = 0, ymax = 0.00, color = 'gray', linestyle = '--')

    #plt.plot(1605.00,90.764009,"ro")
    plt.annotate('', xy=(1605.00, 90.764009), xytext=(0.6, 0.6), textcoords='axes fraction', arrowprops=dict(color='red', shrink=0.05),horizontalalignment='right', verticalalignment='top',)
    #plt.axhline(y = 90.764009, xmin = 0, xmax = 0.7, color = 'gray', linestyle = '--')
    plt.axvline(x = 1605.53, ymin = 0, ymax = 0.61, color = 'gray', linestyle = '--')

    plt.savefig(os.path.join(pasta,"Fr220605.asc"[:8]) + '.jpeg')
    plt.savefig(os.path.join(pasta,"Fr220605.asc"[:8]) + '.png')
    #print(arquivo[:8] + '.txt')
    #plt.close()

# %%
# assign directory
pasta = "Gráficos"
i = 0

f = os.path.join(pasta, "Fr220607.asc")
# checking if it is a file
if os.path.isfile(f):

    #for file in 
    data = np.loadtxt(f, skiprows = 55)
    i = i + 1

    dataX = []
    dataY = []
    for linha in data:
        dataX.append(linha[0])
        dataY.append(linha[1])

    #dataX.reverse()
    #dataY.reverse()
    #dataX = dataX.reverse()
    #dataY = dataY.reverse()

    plt.figure(i, figsize = [16,8])
    plt.plot(dataX,dataY)
    plt.xlim(dataX[0],dataX[-1])
    plt.title('Granalhas de endocarpo sem tratamento - Fr220607')
    plt.xlabel(r'Número de onda ($cm^{-1})$', fontweight='bold')
    plt.ylabel('Reflectância (u.a)', fontweight='bold')
    plt.ylim(min(dataY),max(dataY)+1)

    #plt.plot(2923.52, 93.35,"ro")
    plt.axvline(x = 2923.52, ymin = 0, ymax = 0.70, color = 'gray', linestyle = '--')

    #plt.plot(1032.00, 74.951206,"ro")
    plt.annotate('', xy=(1032.74, 74.951206), xytext=(0.75, 0.1), textcoords='axes fraction', arrowprops=dict(color='red', shrink=0.05),horizontalalignment='right', verticalalignment='top',)
    #plt.axhline(y = 74.951206, xmin = 0, xmax = 0.86, color = 'gray', linestyle = '--')
    plt.axvline(x = 1032.06, ymin = 0, ymax = 0.00, color = 'gray', linestyle = '--')

    #plt.plot(1605.00,90.764009,"ro")
    plt.annotate('', xy=(1605.00, 90.764009), xytext=(0.6, 0.6), textcoords='axes fraction', arrowprops=dict(color='red', shrink=0.05),horizontalalignment='right', verticalalignment='top',)
    #plt.axhline(y = 90.764009, xmin = 0, xmax = 0.7, color = 'gray', linestyle = '--')
    plt.axvline(x = 1605.53, ymin = 0, ymax = 0.61, color = 'gray', linestyle = '--')

    plt.savefig(os.path.join(pasta,"Fr220605.asc"[:8]) + '.jpeg')
    plt.savefig(os.path.join(pasta,"Fr220605.asc"[:8]) + '.png')
    #print(arquivo[:8] + '.txt')
    #plt.close()

# %%
# assign directory
pasta = "Gráficos"
i = 0

fig, axs = plt.subplots(2,sharex = True)
arq = []
picos = []

arq.append(os.path.join(pasta, "Fr220605.asc"))
pico = []
pico.append([2923.52,93.35])
pico.append([1605.60,90.76])
pico.append([1032.00,74.95])
picos.append(pico)
arq.append(os.path.join(pasta, "Fr220607.asc"))
pico = []
pico.append([1719.38,68.40])
pico.append([1228.98,63.37])
pico.append([1008.12,28.05])
picos.append(pico)

data = np.loadtxt(arq[0], skiprows = 55)
i = i + 1

dataX = []
dataY = []
for linha in data:
    dataX.append(linha[0])
    dataY.append(linha[1])

#dataX.reverse()
#dataY.reverse()
#dataX = dataX.reverse()
#dataY = dataY.reverse()

#plt.figure(i, figsize = [16,8])
fig.figsize = [16,8]
axs[0].plot(dataX,dataY)
#axs[0].set_xlim(dataX[0],dataX[-1])
axs[0].set_title('Granalhas de endocarpo sem tratamento - Fr220605')
#axs[0].set_xlabel(r'Número de onda ($cm^{-1})$', fontweight='bold')
axs[0].set_ylabel('Reflectância (u.a)', fontweight='bold')
axs[0].set_ylim(min(dataY),max(dataY)+1)

picoX = picos[0][0][0]
picoY = picos[0][0][1]
axs[0].axvline(x = picoX, ymin = 0, ymax = 0.70, color = 'gray', linestyle = '--')
picoX =  picos[0][1][0]
picoY = picos[0][1][1]
axs[0].annotate('', xy=(picoX, picoY), xytext=(0.6, 0.6), textcoords='axes fraction', arrowprops=dict(color='red', shrink=0.05),horizontalalignment='right', verticalalignment='top',)
axs[0].axvline(x = picoX, ymin = 0, ymax = 0.61, color = 'gray', linestyle = '--')
picoX =  picos[0][2][0]
picoY = picos[0][2][1]
axs[0].annotate('', xy=(picoX, picoY), xytext=(0.75, 0.1), textcoords='axes fraction', arrowprops=dict(color='red', shrink=0.05),horizontalalignment='right', verticalalignment='top',)
axs[0].axvline(x = picoX, ymin = 0, ymax = 0.00, color = 'gray', linestyle = '--')

data = np.loadtxt(arq[1], skiprows = 55)
i = i + 1

dataX = []
dataY = []
for linha in data:
    dataX.append(linha[0])
    dataY.append(linha[1])

#axs[1].figure(i, figsize = [16,8])
axs[1].plot(dataX,dataY)
axs[1].set_xlim(dataX[0],dataX[-1])
axs[1].set_title('Tinta cinza escura da amostra A1 - Fr220607')
axs[1].set_xlabel(r'Número de onda ($cm^{-1})$', fontweight='bold')
axs[1].set_ylabel('Reflectância (u.a)', fontweight='bold')
axs[1].set_ylim(min(dataY),max(dataY)+1)

picoX =  picos[1][0][0]
picoY = picos[1][0][1]
axs[1].axvline(x = picoX, ymin = 0, ymax = 0.65, color = 'gray', linestyle = '--')
picoX =  picos[1][1][0]
picoY = picos[1][1][1]
axs[1].annotate('', xy=(picoX, picoY), xytext=(0.75, 0.6), textcoords='axes fraction', arrowprops=dict(color='red', shrink=0.05),horizontalalignment='right', verticalalignment='top',)
axs[1].axvline(x = picoX, ymin = 0, ymax = 0.56, color = 'gray', linestyle = '--')
picoX =  picos[1][2][0]
picoY = picos[1][2][1]
axs[1].annotate('', xy=(picoX, picoY), xytext=(0.75, 0.1), textcoords='axes fraction', arrowprops=dict(color='red', shrink=0.05),horizontalalignment='right', verticalalignment='top',)
axs[1].axvline(x = picoX, ymin = 0, ymax = 0.00, color = 'gray', linestyle = '--') 

#plt.savefig(os.path.join(pasta,"Fr220607.asc"[:8]) + '.jpeg')
#plt.savefig(os.path.join(pasta,"Fr220607.asc"[:8]) + '.png')
#print(arquivo[:8] + '.txt')
#plt.close()
